# %%
#load the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("dataset_heart.csv")

# %%
data
# Out:
#      age  sex   chest pain type  resting blood pressure  serum cholestoral  \
# 0     70     1                4                     130                322
# 1     67     0                3                     115                564
# 2     57     1                2                     124                261
# 3     64     1                4                     128                263
# 4     74     0                2                     120                269
# ..   ...   ...              ...                     ...                ...
# 265   52     1                3                     172                199
# 266   44     1                2                     120                263
# 267   56     0                2                     140                294
# 268   57     1                4                     140                192
# 269   67     1                4                     160                286
#
#      fasting blood sugar  resting electrocardiographic results  \
# ...

# %%
data.head()
# Out:
#    age  sex   chest pain type  resting blood pressure  serum cholestoral  \
# 0   70     1                4                     130                322
# 1   67     0                3                     115                564
# 2   57     1                2                     124                261
# 3   64     1                4                     128                263
# 4   74     0                2                     120                269
#
#    fasting blood sugar  resting electrocardiographic results  max heart rate  \
# 0                    0                                     2             109
# 1                    0                                     2             160
# 2                    0                                     0             141
# 3                    0                                     0             105
# 4                    0                                     2             121
#
# ...

# %%
data.tail(10)
# Out:
#      age  sex   chest pain type  resting blood pressure  serum cholestoral  \
# 260   58     0                3                     120                340
# 261   60     1                4                     130                206
# 262   58     1                2                     120                284
# 263   49     1                2                     130                266
# 264   48     1                2                     110                229
# 265   52     1                3                     172                199
# 266   44     1                2                     120                263
# 267   56     0                2                     140                294
# 268   57     1                4                     140                192
# 269   67     1                4                     160                286
#
#      fasting blood sugar  resting electrocardiographic results  \
# 260                    0                                     0
# ...

# %%
# Renaming the columns
data.rename(columns={
    'resting electrocardiographic results': 'RER',
    'resting blood pressure': 'RBP',
    'fasting blood sugar': 'FBS'
}, inplace=True)

# %%
data
# Out:
#      age  sex   chest pain type  RBP  serum cholestoral  FBS  RER  \
# 0     70     1                4  130                322    0    2
# 1     67     0                3  115                564    0    2
# 2     57     1                2  124                261    0    0
# 3     64     1                4  128                263    0    0
# 4     74     0                2  120                269    0    2
# ..   ...   ...              ...  ...                ...  ...  ...
# 265   52     1                3  172                199    1    0
# 266   44     1                2  120                263    0    0
# 267   56     0                2  140                294    0    2
# 268   57     1                4  140                192    0    0
# 269   67     1                4  160                286    0    2
#
#      max heart rate  exercise induced angina  oldpeak  ST segment  \
# 0               109                        0      2.4           2
# ...

# %%
data.shape
# Out:
# (270, 14)

# %%
data.dtypes
# Out:
# age                                       int64
# sex                                       int64
# chest pain type                           int64
# resting blood pressure                    int64
# serum cholestoral                         int64
# fasting blood sugar                       int64
# resting electrocardiographic results      int64
# max heart rate                            int64
# exercise induced angina                   int64
# oldpeak                                 float64
# ST segment                                int64
# major vessels                             int64
# thal                                      int64
# heart disease                             int64
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 270 entries, 0 to 269
# Data columns (total 14 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   age                                   270 non-null    int64
#  1   sex                                   270 non-null    int64
#  2   chest pain type                       270 non-null    int64
#  3   resting blood pressure                270 non-null    int64
#  4   serum cholestoral                     270 non-null    int64
#  5   fasting blood sugar                   270 non-null    int64
#  6   resting electrocardiographic results  270 non-null    int64
#  7   max heart rate                        270 non-null    int64
#  8   exercise induced angina               270 non-null    int64
#  9   oldpeak                               270 non-null    float64
#  10  ST segment                            270 non-null    int64
# ...

# %%
data.duplicated().value_counts()
# Out:
# False    270
# Name: count, dtype: int64

# %%
#Count of duplicated rows
data[data.duplicated()].shape
# Out:
# (0, 14)

# %%
# number of patients
patient_count = data.shape[0]

# %%
patient_count
# Out:
# 270

# %%
# no of heart disease persons 1-absence; 2-presence
disease_count = (data['heart disease'] == 2).value_counts()
disease_count
# Out:
# heart disease
# False    150
# True     120
# Name: count, dtype: int64

# %% [markdown]
# ## 120 members have heart disease

# %%
data.describe().T
# Out:
#                          count        mean        std    min    25%    50%  \
# age                      270.0   54.433333   9.109067   29.0   48.0   55.0
# sex                      270.0    0.677778   0.468195    0.0    0.0    1.0
# chest pain type          270.0    3.174074   0.950090    1.0    3.0    3.0
# RBP                      270.0  131.344444  17.861608   94.0  120.0  130.0
# serum cholestoral        270.0  249.659259  51.686237  126.0  213.0  245.0
# FBS                      270.0    0.148148   0.355906    0.0    0.0    0.0
# RER                      270.0    1.022222   0.997891    0.0    0.0    2.0
# max heart rate           270.0  149.677778  23.165717   71.0  133.0  153.5
# exercise induced angina  270.0    0.329630   0.470952    0.0    0.0    0.0
# oldpeak                  270.0    1.050000   1.145210    0.0    0.0    0.8
# ST segment               270.0    1.585185   0.614390    1.0    1.0    2.0
# ...

# %%
# prompt: Distibution curve for all integer variables

for col in data.select_dtypes(include=['int64']):
  plt.figure(figsize=(5, 5))
  plt.hist(data[col], bins=10, edgecolor="black")
  plt.title(f"Distribution of {col}")
  plt.show()

# %% [markdown]
# ### Data is bias with 60 Y people
#
# Male Female diffeence is high

# %%
# prompt: relation between columns

data.corr()
# Out:
#                               age      sex   chest pain type       RBP  \
# age                      1.000000 -0.094401         0.096920  0.273053
# sex                     -0.094401  1.000000         0.034636 -0.062693
# chest pain type          0.096920  0.034636         1.000000 -0.043196
# RBP                      0.273053 -0.062693        -0.043196  1.000000
# serum cholestoral        0.220056 -0.201647         0.090465  0.173019
# FBS                      0.123458  0.042140        -0.098537  0.155681
# RER                      0.128171  0.039253         0.074325  0.116157
# max heart rate          -0.402215 -0.076101        -0.317682 -0.039136
# exercise induced angina  0.098297  0.180022         0.353160  0.082793
# oldpeak                  0.194234  0.097412         0.167244  0.222800
# ST segment               0.159774  0.050545         0.136900  0.142472
# major vessels            0.356081  0.086830         0.225890  0.085697
# ...

# %%
data.corr() > 0.5
# Out:
#                            age   sex   chest pain type    RBP  \
# age                       True  False            False  False
# sex                      False   True            False  False
# chest pain type          False  False             True  False
# RBP                      False  False            False   True
# serum cholestoral        False  False            False  False
# FBS                      False  False            False  False
# RER                      False  False            False  False
# max heart rate           False  False            False  False
# exercise induced angina  False  False            False  False
# oldpeak                  False  False            False  False
# ST segment               False  False            False  False
# major vessels            False  False            False  False
# thal                     False  False            False  False
# heart disease            False  False            False  False
#
# ...

# %%
# Calculating the correlation matrix
corr_matrix = data.corr()

# Filtering the correlation matrix to find values where correlation is more than 0.5
high_corr = corr_matrix[corr_matrix > 0.5]

# Removing self-correlations by setting diagonal to NaN
#pd.set_option('display.max_columns', None)  # Optional: to ensure all columns are displayed
#for col in high_corr.columns:
#    high_corr.loc[col, col] = pd.NA

print(high_corr)
# Out:
#                          age  sex   chest pain type  RBP  serum cholestoral  \
# age                      1.0   NaN              NaN  NaN                NaN
# sex                      NaN   1.0              NaN  NaN                NaN
# chest pain type          NaN   NaN              1.0  NaN                NaN
# RBP                      NaN   NaN              NaN  1.0                NaN
# serum cholestoral        NaN   NaN              NaN  NaN                1.0
# FBS                      NaN   NaN              NaN  NaN                NaN
# RER                      NaN   NaN              NaN  NaN                NaN
# max heart rate           NaN   NaN              NaN  NaN                NaN
# exercise induced angina  NaN   NaN              NaN  NaN                NaN
# oldpeak                  NaN   NaN              NaN  NaN                NaN
# ST segment               NaN   NaN              NaN  NaN                NaN
# ...

# %%
# Create the default pairplot
sns.pairplot(data)
